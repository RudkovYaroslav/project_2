# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Ярослав, привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделал большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать дата-специалистом.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Вам нужно научиться определять рыночную стоимость объектов недвижимости. Для этого проведите исследовательский анализ данных и установите параметры, влияющие на цену объектов. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта и других объектов — эти данные автоматически получены из геосервисов. Количество парков и водоёмов также заполняется без участия пользователя.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Отличная практика - расписывать цель и основные этапы своими словами (этот навык очень поможет на фильнальном проекте). Хорошо было бы добавить ход и цель исследования. Вот мой личный пример:
#
# ![image.png](attachment:image.png)
#
#
# ---
#
# `PS: из-за этого сообщения может часто возникать ошибка в ноутбуке`. Если мешает, можешь удалить данный комментарий
# </div>

# %% [markdown]
# <div style="border:solid Aqua 3px; padding: 20px">
#
# __Комментарий №2__
#
# Запомню про это, но в этой работе уже не вижу смысла :) У тебя очень хорошо получилось.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <h3> Вступление  <a class="tocSkip"></h3>
#     Уважаемый ревьювер, добрый вечер. Изначально буду обращаться на Вы, так как не знаком еще, но буду рад познакомиться :)
#
# Проект оказался непростым по некоторым причинам, которые я хочу огласить сразу:
#
# Есть небольшие сомнения насчет предобработки. Какие значения пропустил, а какие заменил. По итогу я старался сохранить как можно больше данных и вроде как на финальный результат это не повлияло, но все равно, может я мог еще больше удалить строк для чистоты датафрейма?
#
# Стоит ли в середине выводить такие вещи как df и df.info()? Потому что при работе у меня они всегда рядом, чтобы не листать а потом я просто все удалил.
#
# Нормально ли то, что по итогу получились "Очевидные выводы"?
#
# В целом я думаю пока все. Очень надеюсь, что проект Вас не разочарует.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Спасибо за вопросы, отвечаю:
#
# 1. По поводу предобработки отвечу ниже в ревью
#
# 2. Да, можно выводить info()
#
# 3. Не переживай, это действительно сложный и самый объемный проект за обучение)

# %% [markdown]
# <div style="border:solid Aqua 3px; padding: 20px">
#
# __Комментарий №1__
#
# Вот так будут выглядеть мои комментарии, когда у меня есть вопросы или сомнения

# %% [markdown]
# <div style="border:solid Aqua 3px; padding: 20px">
#
# __Комментарий №2__
#
# Александр, напишу все, что я изменил, чтобы детально не вглядываться еще раз.
#
# - 1 Под всеми твоими комментариями, если я что-то изменил, то поставил ✔️
# - 2 Постарался графики привести к желанному виду, все оси и названия русифицировал
# - 3 У меня все никак не может из головы вылезти попытка записать месяцы по-русски в пункте 3.2. Можешь, пожалуйста, посмотреть и дать комментарии/кинуть источники какие-нибудь на эту тему, чтобы понять, как заставить систему выводить на своем, РУССКОМ языке(Ведь в системе он есть, и даже, вроде как, так записан)
# - 4 К сожалению, предложенный метод округления не подошел. У меня самого были задумки, по типу написать
# ```python
# df['x'] = int(((df[~df['city_center_nearest'].isna()]['city_center_nearest'] /1000)+0,5)*10)/10
# ```
# А все, я понял, у меня тоже не получилось бы. Вообщем это сложно как-то. Много запариваться ради мелочей, так что не выгодно тратить столько времени

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию

# %% [markdown]
# Импорт требуемых библиотек

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Установка стандартных значений размера для выводимых графиков

# %%
plt.rcParams["figure.figsize"] = (15,5)

# %% [markdown]
# Чтение DataFrame

# %%
df = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Предлагаю разделять логически разные вещи:
#
#     - импорты библиотек
#     - открытие данных (это может быть не тривиальный процесс)
#     - рабочий код
#
# Такой подход позволит улучшить читаемость кода, снизит время поиска ошибок если они есть и исключит повторное выполнение кода

# %% [markdown]
# ✔️

# %%
df.head(5)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# 1          11.0      2.0   посёлок Шушары           12817.0
# 2           8.3      0.0  Санкт-Петербург           21741.0
# 3           NaN      0.0  Санкт-Петербург           28098.0
# 4          41.0      NaN  Санкт-Петербург           31856.0
#
#   cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0             16028.0               1.0          482.0               2.0
# 1             18603.0               0.0            NaN               0.0
# 2             13933.0               1.0           90.0               2.0
# 3              6800.0               2.0           84.0               3.0
# 4              8098.0               2.0          112.0               1.0
#
#    ponds_nearest  days_exposition
# 0          755.0              NaN
# 1            NaN             81.0
# 2          574.0            558.0
# 3          234.0            424.0
# 4           48.0            121.0
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
#  15  airports_nearest      18157 non-null  float64
#  16  cityCenters_nearest   18180 non-null  float64
#  17  parks_around3000      18181 non-null  float64
#  18  parks_nearest         8079 non-null   float64
#  19  ponds_around3000      18181 non-null  float64
#  20  ponds_nearest         9110 non-null   float64
#  21  days_exposition       20518 non-null  float64
# dtypes: bool(2), float64(14), int64(3), object(3)
# memory usage: 3.7+ MB

# %%
df.hist(figsize=(20, 20))
pass #Чтобы не было лишних слов в выводе

# %% [markdown]
# **Вывод по разделу 1:**
#
# Ознакомились с DataFrame. Изначально можно уже выделить определенное количество проблем, с которыми придется столкнуться при предобработке, но данные выглядят многообещающе.Гистограммы по большей части представляют нормальное распределение(или Bell-curve) там, где оно должно быть.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
# __Комментарий от ревьюера №1__
#
# Отлично! Первый взгляд на данные есть

# %% [markdown]
# ### Выполните предобработку данных

# %%
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Проверить колличество пропусков в % можно вот так:
#
#
#     pd.DataFrame(round(df.isna().mean()*100,)).style.background_gradient('coolwarm')

# %% [markdown]
# <div style="border:solid Aqua 3px; padding: 20px">
#
# __Комментарий №2__
#
# Спасибо большое за совет, я пока что еще не дошел до градиента, а тем более его применения. Точно заберу себе такой вариант для дальнейших проектов ;)

# %%
pd.DataFrame(round(df.isna().mean()*100)).sort_values(by=0, ascending=False).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_20aba_row0_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_20aba_row1_col0{
#             background-color:  #f4987a;
#             color:  #000000;
#         }#T_20aba_row2_col0{
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }#T_20aba_row3_col0{
#             background-color:  #ead4c8;
#             color:  #000000;
#         }#T_20aba_row4_col0{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_20aba_row5_col0,#T_20aba_row6_col0,#T_20aba_row7_col0,#T_20aba_row8_col0{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_20aba_row9_col0{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_20aba_row10_col0{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_20aba_row11_col0{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_20aba_row12_col0,#T_20aba_row13_col0,#T_20aba_row14_col0,#T_20aba_row15_col0,#T_20aba_row16_col0,#T_20aba_row17_col0,#T_20aba_row18_col0,#T_20aba_row19_col0,#T_20aba_row20_col0,#T_20aba_row21_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_20aba_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_20aba_level0_row0" class="row_heading level0 row0" >is_apartment</th>
#                         <td id="T_20aba_row0_col0" class="data row0 col0" >88.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_20aba_level0_row1" class="row_heading level0 row1" >parks_nearest</th>
#                         <td id="T_20aba_row1_col0" class="data row1 col0" >66.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_20aba_level0_row2" class="row_heading level0 row2" >ponds_nearest</th>
#                         <td id="T_20aba_row2_col0" class="data row2 col0" >62.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_20aba_level0_row3" class="row_heading level0 row3" >balcony</th>
#                         <td id="T_20aba_row3_col0" class="data row3 col0" >49.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_20aba_level0_row4" class="row_heading level0 row4" >ceiling_height</th>
#                         <td id="T_20aba_row4_col0" class="data row4 col0" >39.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_20aba_level0_row5" class="row_heading level0 row5" >ponds_around3000</th>
#                         <td id="T_20aba_row5_col0" class="data row5 col0" >23.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_20aba_level0_row6" class="row_heading level0 row6" >parks_around3000</th>
#                         <td id="T_20aba_row6_col0" class="data row6 col0" >23.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_20aba_level0_row7" class="row_heading level0 row7" >cityCenters_nearest</th>
#                         <td id="T_20aba_row7_col0" class="data row7 col0" >23.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_20aba_level0_row8" class="row_heading level0 row8" >airports_nearest</th>
#                         <td id="T_20aba_row8_col0" class="data row8 col0" >23.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_20aba_level0_row9" class="row_heading level0 row9" >days_exposition</th>
#                         <td id="T_20aba_row9_col0" class="data row9 col0" >13.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_20aba_level0_row10" class="row_heading level0 row10" >kitchen_area</th>
#                         <td id="T_20aba_row10_col0" class="data row10 col0" >10.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_20aba_level0_row11" class="row_heading level0 row11" >living_area</th>
#                         <td id="T_20aba_row11_col0" class="data row11 col0" >8.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_20aba_level0_row12" class="row_heading level0 row12" >locality_name</th>
#                         <td id="T_20aba_row12_col0" class="data row12 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_20aba_level0_row13" class="row_heading level0 row13" >total_images</th>
#                         <td id="T_20aba_row13_col0" class="data row13 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_20aba_level0_row14" class="row_heading level0 row14" >last_price</th>
#                         <td id="T_20aba_row14_col0" class="data row14 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_20aba_level0_row15" class="row_heading level0 row15" >studio</th>
#                         <td id="T_20aba_row15_col0" class="data row15 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_20aba_level0_row16" class="row_heading level0 row16" >floor</th>
#                         <td id="T_20aba_row16_col0" class="data row16 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_20aba_level0_row17" class="row_heading level0 row17" >floors_total</th>
#                         <td id="T_20aba_row17_col0" class="data row17 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_20aba_level0_row18" class="row_heading level0 row18" >rooms</th>
#                         <td id="T_20aba_row18_col0" class="data row18 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_20aba_level0_row19" class="row_heading level0 row19" >first_day_exposition</th>
#                         <td id="T_20aba_row19_col0" class="data row19 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_20aba_level0_row20" class="row_heading level0 row20" >total_area</th>
#                         <td id="T_20aba_row20_col0" class="data row20 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_20aba_level0_row21" class="row_heading level0 row21" >open_plan</th>
#                         <td id="T_20aba_row21_col0" class="data row21 col0" >0.000000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **Для простоты пойдем по списку**

# %% [markdown]
# - **1** Ceiling_height заменим значения на средние, опираясь на местоположение, так как там обычно свои стандарты применяются при строительстве

# %%
for d in df['locality_name'].unique():
    df.loc[(df['locality_name'] == d) & (df['ceiling_height'].isna()), 'ceiling_height']\
    = round(df[df['locality_name'] == d]['ceiling_height'].mean(), 2)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Молодец, что используешь собственные функции

# %% [markdown]
# - **2** Floors_total оставим без изменений, так как 86 пропусков не так уж и много

# %% [markdown]
# - **3** Living_area также оставим как есть. Решение проблемы пропусков займет слишком много времени, а еще не очень понятно, на каком основании вставлять значения.

# %% [markdown]
# - 4 Is_apartment  проверим, есть ли заивсимость по цене у того, что имеем

# %%
df['is_apartment'].value_counts()
# Out:
# False    2725
# True       50
# Name: is_apartment, dtype: int64

# %%
df[df['is_apartment'] == True].sort_values('last_price') #Проверим цены у апартаментов, можем ли по ним базировать выбор
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 1608             12   2150000.0       20.10  2019-01-30T00:00:00      1
# 11779            12   2290000.0       43.00  2017-06-09T00:00:00      2
# 12160             8   2450000.0       43.00  2018-08-14T00:00:00      1
# 7056              8   3500000.0       56.40  2016-04-06T00:00:00      2
# 20534            18   3600000.0       31.23  2016-04-13T00:00:00      1
# 11179             8   3676365.0       33.00  2018-07-23T00:00:00      1
# 5076              0   3850000.0       30.50  2018-10-03T00:00:00      1
# 22938            14   4000000.0       98.00  2018-03-15T00:00:00      4
# 19034            20   4100000.0       32.00  2017-04-07T00:00:00      1
# 3951             10   4300000.0       50.00  2019-04-20T00:00:00      1
# 7362             18   4300000.0       41.76  2018-06-12T00:00:00      1
# 3816              4   4779000.0       53.10  2016-05-16T00:00:00      1
# 16166            13   4792000.0       49.00  2017-08-07T00:00:00      1
# 19017            12   4887000.0       52.40  2018-03-19T00:00:00      1
# 2975              9   4931398.0       42.90  2018-07-23T00:00:00      1
# 7206              7   5289476.0       46.90  2018-07-18T00:00:00      1
# 20008             8   5400000.0       31.00  2018-02-21T00:00:00      1
# 22560            15   5500000.0       98.00  2018-12-09T00:00:00      3
# 21244            10   5500000.0       58.00  2018-12-13T00:00:00      3
# 21458             7   5616379.0       47.40  2018-07-23T00:00:00      1
# 8611              6   6030000.0       50.40  2018-02-20T00:00:00      2
# 6871             14   6100000.0       58.00  2018-07-25T00:00:00      2
# 15788            16   6390000.0       58.70  2018-03-18T00:00:00      1
# 3067             13   6600000.0       95.00  2018-09-08T00:00:00      2
# 4339             19   6900000.0       72.00  2019-03-25T00:00:00      3
# 18431            19   6900000.0       93.00  2018-02-22T00:00:00      3
# 19691            16   7000000.0       52.80  2018-11-15T00:00:00      2
# 6523             11   7500000.0       82.00  2019-04-20T00:00:00      2
# 2759             11   7500000.0      152.00  2018-07-27T00:00:00      3
# 5809             10   7900000.0       74.00  2019-02-12T00:00:00      3
# 916              11   8183000.0       70.00  2018-01-11T00:00:00      2
# 5654             20   9200000.0      116.00  2019-04-26T00:00:00      3
# 14459             4   9635328.0       76.80  2018-10-01T00:00:00      1
# 20368             8   9897258.0       85.20  2018-07-23T00:00:00      3
# 6561             20  10500000.0      100.00  2019-03-22T00:00:00      3
# 22941             8  10965000.0       69.30  2019-01-10T00:00:00      1
# 6353              0  11620701.0      122.30  2018-10-01T00:00:00      2
# 8252             15  12750000.0      102.00  2018-10-17T00:00:00      3
# 543              11  12790000.0       56.60  2018-11-06T00:00:00      2
# 14603            12  13490000.0      100.60  2018-07-31T00:00:00      7
# 17196             7  13900000.0       50.00  2016-10-24T00:00:00      1
# 23236            18  13900000.0       95.00  2017-10-15T00:00:00      3
# 22869             0  15000000.0       25.00  2018-07-25T00:00:00      1
# 10390            18  30000000.0      137.00  2018-08-07T00:00:00      3
# 1109              1  34878556.0       95.80  2014-12-09T00:00:00      2
# 7521             16  43500000.0      245.80  2015-12-17T00:00:00      3
# 5297             19  45000000.0       96.00  2018-11-15T00:00:00      2
# 11492             1  46424072.0       92.40  2014-12-09T00:00:00      2
# 10867             1  56844500.0      177.90  2015-01-15T00:00:00      3
# 8018             20  84000000.0      507.00  2015-12-17T00:00:00      5
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 1608             2.80           9.0          NaN      1         True  ...
# 11779            2.50           5.0    29.000000      2         True  ...
# 12160            2.75           5.0    16.000000      1         True  ...
# 7056             2.60           5.0    31.000000      2         True  ...
# 20534            2.80          23.0    15.000000     11         True  ...
# 11179            3.00           4.0    27.060000      1         True  ...
# 5076            24.00           5.0    19.500000      1         True  ...
# 22938           27.00           2.0    73.000000      2         True  ...
# 19034            2.70          27.0    16.000000     22         True  ...
# 3951             3.00          11.0    17.000000      9         True  ...
# 7362             2.65          20.0    13.920000      6         True  ...
# 3816             2.80          13.0    19.800000      6         True  ...
# 16166            3.12           4.0    21.000000      3         True  ...
# 19017            3.10           4.0    24.700000      2         True  ...
# 2975             3.15           4.0    20.390000      3         True  ...
# 7206             3.15           4.0    16.470000      2         True  ...
# 20008            2.75           9.0    20.000000      5         True  ...
# 22560            2.60           8.0          NaN      2         True  ...
# 21244            2.60           9.0    41.000000      2         True  ...
# 21458            3.00           4.0    20.520000      3         True  ...
# 8611             3.10           4.0    37.000000      2         True  ...
# 6871             3.10           4.0          NaN      3         True  ...
# 15788            3.12           4.0    31.500000      3         True  ...
# 3067             4.50           7.0    45.000000      7         True  ...
# 4339             3.50           4.0    70.000000      1         True  ...
# 18431            3.00           5.0    67.000000      4         True  ...
# 19691            2.70          16.0    28.900002     13         True  ...
# 6523             3.00          11.0    30.000000      9         True  ...
# 2759             3.00           3.0          NaN      1         True  ...
# 5809             3.55           6.0    56.000000      3         True  ...
# 916              3.12           3.0    40.000000      3         True  ...
# 5654             3.20           5.0    68.000000      5         True  ...
# 14459            2.80           3.0          NaN      3         True  ...
# 20368            3.00           4.0    48.480000      3         True  ...
# 6561             2.65           4.0    51.000000      4         True  ...
# 22941            3.00           4.0    48.900000      4         True  ...
# 6353             2.80           3.0          NaN      3         True  ...
# 8252             2.80           7.0    61.000000      4         True  ...
# 543              3.50           3.0    29.400000      1         True  ...
# 14603            2.80           4.0          NaN      2         True  ...
# 17196            4.00           3.0    35.000000      2         True  ...
# 23236            2.80          15.0    50.000000     15         True  ...
# 22869          100.00           5.0    14.000000      5         True  ...
# 10390            3.00           5.0    90.000000      4         True  ...
# 1109             2.80           6.0    58.300000      5         True  ...
# 7521             4.45           7.0   170.800000      7         True  ...
# 5297             3.20           6.0          NaN      4         True  ...
# 11492            2.80           6.0    54.800000      6         True  ...
# 10867            2.80           6.0    87.200000      5         True  ...
# 8018             4.45           7.0   301.500000      7         True  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 1608            NaN      NaN  Санкт-Петербург           26646.0
# 11779          5.00      1.0  посёлок Щеглово               NaN
# 12160           NaN      NaN  Санкт-Петербург           26069.0
# 7056          10.00      1.0       Никольское               NaN
# 20534         10.00      2.0  Санкт-Петербург           33705.0
# 11179           NaN      NaN  Санкт-Петербург           46015.0
# 5076           5.50      NaN  Санкт-Петербург           29686.0
# 22938          9.00      1.0   деревня Нижняя               NaN
# 19034          8.00      1.0  Санкт-Петербург           20998.0
# 3951          12.00      2.0  Санкт-Петербург           10143.0
# 7362          11.37      2.0  Санкт-Петербург           39141.0
# 3816          15.90      2.0  Санкт-Петербург           19396.0
# 16166         13.60      2.0  Санкт-Петербург           44870.0
# 19017         11.70      5.0  Санкт-Петербург           44870.0
# 2975          10.29      NaN  Санкт-Петербург           44870.0
# 7206          14.46      1.0  Санкт-Петербург           44870.0
# 20008          6.50      NaN  Санкт-Петербург           27747.0
# 22560         28.00      NaN     Красное Село           27164.0
# 21244          7.00      5.0  Санкт-Петербург           28632.0
# 21458         14.04      2.0  Санкт-Петербург           44870.0
# 8611          11.00      NaN  Санкт-Петербург           45767.0
# 6871            NaN      NaN  Санкт-Петербург           45942.0
# 15788         11.70      2.0  Санкт-Петербург           44870.0
# 3067          25.00      2.0           Выборг               NaN
# 4339            NaN      NaN  Санкт-Петербург           31487.0
# 18431           NaN      2.0           Выборг               NaN
# 19691          9.50      1.0  Санкт-Петербург            8426.0
# 6523          31.00      2.0  Санкт-Петербург           10143.0
# 2759            NaN      1.0       Всеволожск               NaN
# 5809            NaN      NaN  Санкт-Петербург           31006.0
# 916             NaN      2.0  Санкт-Петербург           45796.0
# 5654          32.00      2.0           Выборг               NaN
# 14459           NaN      NaN  Санкт-Петербург           44870.0
# 20368         10.20      2.0  Санкт-Петербург           44870.0
# 6561            NaN      NaN  Санкт-Петербург           44812.0
# 22941           NaN      2.0      Зеленогорск           73391.0
# 6353            NaN      NaN  Санкт-Петербург           44870.0
# 8252          12.00      5.0          Колпино           26100.0
# 543             NaN      NaN         Петергоф           35248.0
# 14603           NaN      NaN  Санкт-Петербург           24309.0
# 17196          9.00      NaN  Санкт-Петербург           24418.0
# 23236         11.00      4.0  Санкт-Петербург           27573.0
# 22869         11.00      5.0  Санкт-Петербург           34963.0
# 10390         12.00      NaN  Санкт-Петербург           23832.0
# 1109          20.00      1.0  Санкт-Петербург           21860.0
# 7521          25.00      1.0  Санкт-Петербург               NaN
# 5297          45.00      1.0  Санкт-Петербург           21860.0
# 11492         20.00      1.0  Санкт-Петербург           21860.0
# 10867         87.20      NaN  Санкт-Петербург           21860.0
# 8018          45.50      1.0  Санкт-Петербург               NaN
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 1608              12147.0               0.0            NaN               0.0
# 11779                 NaN               NaN            NaN               NaN
# 12160             29493.0               0.0            NaN               0.0
# 7056                  NaN               NaN            NaN               NaN
# 20534             14883.0               0.0            NaN               0.0
# 11179             20802.0               0.0            NaN               1.0
# 5076               8389.0               3.0          397.0               1.0
# 22938                 NaN               NaN            NaN               NaN
# 19034             22710.0               0.0            NaN               1.0
# 3951              11367.0               0.0            NaN               0.0
# 7362              15985.0               0.0            NaN               0.0
# 3816               4516.0               0.0            NaN               1.0
# 16166             20802.0               0.0            NaN               1.0
# 19017             20802.0               0.0            NaN               1.0
# 2975              20802.0               0.0            NaN               1.0
# 7206              20802.0               0.0            NaN               1.0
# 20008              6450.0               3.0          246.0               3.0
# 22560             30589.0               0.0            NaN               0.0
# 21244             13261.0               0.0            NaN               1.0
# 21458             20802.0               0.0            NaN               0.0
# 8611              21700.0               0.0            NaN               1.0
# 6871              20802.0               0.0            NaN               1.0
# 15788             21689.0               0.0            NaN               1.0
# 3067                  NaN               NaN            NaN               NaN
# 4339               4466.0               2.0          353.0               1.0
# 18431                 NaN               NaN            NaN               NaN
# 19691             12082.0               2.0           24.0               1.0
# 6523              11367.0               0.0            NaN               0.0
# 2759                  NaN               NaN            NaN               NaN
# 5809               3075.0               2.0          123.0               3.0
# 916               21729.0               0.0            NaN               1.0
# 5654                  NaN               NaN            NaN               NaN
# 14459             20802.0               0.0            NaN               1.0
# 20368             20802.0               0.0            NaN               0.0
# 6561              10500.0               0.0            NaN               0.0
# 22941             54490.0               3.0            4.0               1.0
# 6353              20802.0               0.0            NaN               1.0
# 8252              31886.0               2.0          332.0               2.0
# 543               30437.0               3.0           53.0               3.0
# 14603              3876.0               3.0          574.0               3.0
# 17196              1740.0               1.0          573.0               3.0
# 23236              9436.0               1.0          714.0               0.0
# 22869              8283.0               1.0          223.0               3.0
# 10390              1285.0               3.0          374.0               3.0
# 1109                318.0               2.0          160.0               3.0
# 7521               5735.0               2.0          110.0               0.0
# 5297                318.0               2.0          160.0               3.0
# 11492               318.0               2.0          160.0               3.0
# 10867               318.0               2.0          160.0               3.0
# 8018               5735.0               2.0          110.0               0.0
#
#        ponds_nearest  days_exposition
# 1608             NaN             13.0
# 11779            NaN             46.0
# 12160            NaN              8.0
# 7056             NaN            635.0
# 20534            NaN            767.0
# 11179          792.0              NaN
# 5076           578.0              7.0
# 22938            NaN             27.0
# 19034          767.0            388.0
# 3951             NaN              NaN
# 7362             NaN             44.0
# 3816           826.0             60.0
# 16166          792.0            337.0
# 19017          792.0            113.0
# 2975           792.0            273.0
# 7206           792.0            278.0
# 20008          177.0              8.0
# 22560            NaN              7.0
# 21244          544.0             12.0
# 21458            NaN              NaN
# 8611           576.0              NaN
# 6871           792.0            126.0
# 15788          789.0            114.0
# 3067             NaN             96.0
# 4339           439.0             22.0
# 18431            NaN             56.0
# 19691          271.0            165.0
# 6523             NaN              NaN
# 2759             NaN              7.0
# 5809           274.0              6.0
# 916            754.0            179.0
# 5654             NaN              NaN
# 14459          792.0             30.0
# 20368            NaN              NaN
# 6561             NaN              NaN
# 22941          217.0            110.0
# 6353           792.0              NaN
# 8252           472.0            172.0
# 543             22.0              NaN
# 14603          325.0             50.0
# 17196          321.0            869.0
# 23236            NaN              7.0
# 22869           30.0             19.0
# 10390           32.0             34.0
# 1109           569.0           1572.0
# 7521             NaN           1067.0
# 5297           569.0              NaN
# 11492          569.0           1030.0
# 10867          569.0              NaN
# 8018             NaN           1078.0
#
# [50 rows x 22 columns]

# %%
df['is_apartment'] = df['is_apartment'].fillna(False)

# %% [markdown]
# Нет явной зависимости = ставим False

# %% [markdown]
# - 5 Kitchen_area оставим как есть. Решение проблемы пропусков займет слишком много времени, а еще не очень понятно, на каком основании вставлять значения.

# %% [markdown]
# - 6 Balcony посмотрим, что имеем:

# %%
df['balcony'].value_counts()
# Out:
# 1.0    4195
# 0.0    3758
# 2.0    3659
# 5.0     304
# 4.0     183
# 3.0      81
# Name: balcony, dtype: int64

# %%
df.plot(y='balcony', x='rooms', kind='scatter')
df.plot(x='balcony', y='last_price', kind='scatter')
pass

# %% [markdown]
# Мы не можем фактически поставить зависимость между количеством балконов и ценой/количеством комнат, поэтому заменим все пропуски на 0.(И да, 5 балконов действительно может существовать)

# %%
df['balcony'] = df['balcony'].fillna(0)
df['balcony'].value_counts()
# Out:
# 0.0    15277
# 1.0     4195
# 2.0     3659
# 5.0      304
# 4.0      183
# 3.0       81
# Name: balcony, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Согласен, если пропуск - вероятнее всего балкон отсутствует

# %% [markdown]
# - 7 Locality_name  оставим, как есть, но пропуски заменим на unknown

# %%
df['locality_name'] = df['locality_name'].fillna('Unknown')

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Ты выбрал самый правильный способ замены пропусков в категориальном столбце - замена на значение-заглушку

# %% [markdown]
# - 8 Airports_nearest нужно оставить NaN, так как мы не можем заменить на 0. NaN появился из-за того что нет аэропорта в ближайшей доступности, но это не значит что расстояние 0. Также не значит, что можем заменить на медианное. Можем только оставить NaN

# %% [markdown]
# - 9 cityCenters_nearest проверим одну теорию:

# %%
df[(df['cityCenters_nearest'].isna()) & (df['parks_around3000'].isna()) & (df['ponds_around3000'].isna())]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 5                10   2890000.0       30.40  2018-09-10T00:00:00      1
# 8                20   2900000.0       33.16  2018-05-23T00:00:00      1
# 12               10   3890000.0       54.00  2016-06-30T00:00:00      2
# 22               20   5000000.0       58.00  2017-04-24T00:00:00      2
# 30               12   2200000.0       32.80  2018-02-19T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 23683            16   2100000.0       62.80  2018-09-18T00:00:00      4
# 23692             2   1350000.0       30.00  2017-07-07T00:00:00      1
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 5                2.62          12.0        14.40      5         False  ...
# 8                2.94          27.0        15.43     26         False  ...
# 12               2.66           5.0        30.00      5         False  ...
# 22               2.75          25.0        30.00     15         False  ...
# 30               2.63           9.0          NaN      2         False  ...
# ...               ...           ...          ...    ...           ...  ...
# 23683            2.50           5.0        45.50      3         False  ...
# 23692            2.61           5.0        17.50      4         False  ...
# 23695            2.54           5.0        38.00      4         False  ...
# 23696             NaN           3.0        29.70      1         False  ...
# 23698            2.50           5.0        12.30      1         False  ...
#
#        kitchen_area  balcony              locality_name  airports_nearest  \
# 5              9.10      0.0  городской посёлок Янино-1               NaN
# 8              8.81      0.0             посёлок Мурино               NaN
# 12             9.00      0.0                  Сертолово               NaN
# 22            11.00      2.0            деревня Кудрово               NaN
# 30              NaN      0.0                   Коммунар               NaN
# ...             ...      ...                        ...               ...
# 23683          5.50      0.0       посёлок Дзержинского               NaN
# 23692          6.00      0.0                     Тихвин               NaN
# 23695          8.50      0.0                      Тосно               NaN
# 23696           NaN      0.0           село Рождествено               NaN
# 23698          9.00      0.0        поселок Новый Учхоз               NaN
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 5                     NaN               NaN            NaN               NaN
# 8                     NaN               NaN            NaN               NaN
# 12                    NaN               NaN            NaN               NaN
# 22                    NaN               NaN            NaN               NaN
# 30                    NaN               NaN            NaN               NaN
# ...                   ...               ...            ...               ...
# 23683                 NaN               NaN            NaN               NaN
# 23692                 NaN               NaN            NaN               NaN
# 23695                 NaN               NaN            NaN               NaN
# 23696                 NaN               NaN            NaN               NaN
# 23698                 NaN               NaN            NaN               NaN
#
#        ponds_nearest  days_exposition
# 5                NaN             55.0
# 8                NaN            189.0
# 12               NaN             90.0
# 22               NaN             60.0
# 30               NaN             63.0
# ...              ...              ...
# 23683            NaN              NaN
# 23692            NaN            413.0
# 23695            NaN             45.0
# 23696            NaN              NaN
# 23698            NaN              NaN
#
# [5518 rows x 22 columns]

# %% [markdown]
# Как мы видим - все пропуски взаимосвязаны в этих 3 категориях. Можем лишь заменить два столбца на 0, так как они категориальные и по факту будут отображать количество ближайших парков/озер в 0. Остальные оставим так, как есть из-за той же причины, что и с аэропортами.

# %%
df[['parks_around3000','ponds_around3000']] = df[['parks_around3000','ponds_around3000']].fillna(0)

# %% [markdown]
# - 10 Days_exposition самое логичное - что объявление еще висит. Значит оставляем NaN, так как нам нужно будет проделывать операции

# %% [markdown]
# Дальше разберемся с типами данных:

# %%
df['last_price'] = df['last_price'].astype(int)

# %%
df['balcony'] = df['balcony'].astype(int)

# %%
df['parks_around3000'] = df['parks_around3000'].astype(int)
df['ponds_around3000'] = df['ponds_around3000'].astype(int)

# %% [markdown]
# Заменили все численные на реально численные, кроме тех колонок, где мы оставили NaN, так как там не получится заменить.

# %%
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format='%Y%m%dT%H:%M:%S')

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Столбцы имеют корректный тип данных

# %% [markdown]
# Преобразуем дату в формат даты

# %%
df['locality_name'] = df['locality_name'].str.replace('ё', 'е')\
.replace(['поселок городского', 'городской поселок', 'поселок городского типа'], 'поселок', regex=True)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Можно например вот так:
#
#     df = df.apply(lambda x: x.replace({'поселок':'посёлок', 'городской посёлок': 'посёлок', 'посёлок городского типа': 'посёлок', 'коттеджный посёлок': 'посёлок', 'посёлок при железнодорожной станции': 'посёлок станции'}, regex=True))
#
#     len(df.locality_name.unique())
#
# </div>

# %% [markdown]
# <div style="border:solid Aqua 3px; padding: 20px">
#
# __Комментарий №2__
#
# Изначально я как раз и хотел таким способом, но названий оч много и я подумал, что так эффективнее(В данном исследовании, потому что тут созданные условия). В реальности в таких случаях скорее всего действительно придется шерстить unique и приводить все знаения под один стандарт бесконечным перечислением

# %% [markdown]
# Заменим названия на приведенные к общему стандарту

# %% [markdown]
# Посмотрим на очевидные выбросы:

# %%
df.boxplot(column='last_price', figsize=(10,10))
pass

# %% [markdown]
# Тут видим, что есть совсем чуть-чуть значений, которые сильно выбиваются. Лучше от них избавиться

# %%
df.sort_values('last_price', ascending=False).head(15)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 12971            19   763000000       400.0           2017-09-30      7
# 19540             8   420000000       900.0           2017-12-06     12
# 14706            15   401300000       401.0           2016-02-20      5
# 1436             19   330000000       190.0           2018-04-04      3
# 15651            20   300000000       618.0           2017-12-18      7
# 22831            18   289238400       187.5           2019-03-19      2
# 16461            17   245000000       285.7           2017-04-10      6
# 13749             7   240000000       410.0           2017-04-01      6
# 5893              3   230000000       500.0           2017-05-31      6
# 8900             13   190870000       268.0           2016-03-25      3
# 19865            20   180000000       347.0           2015-01-21      8
# 19155            20   160000000       243.0           2018-11-12      5
# 2536             16   159984000       242.4           2015-08-27      4
# 16495            12   159000000       260.0           2017-04-04      4
# 1026             20   155000000       310.0           2018-10-12      5
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 12971            2.80          10.0        250.0     10         False  ...
# 19540            2.80          25.0        409.7     25         False  ...
# 14706            2.80           9.0        204.0      9         False  ...
# 1436             3.50           7.0         95.0      5         False  ...
# 15651            3.40           7.0        258.0      5         False  ...
# 22831            3.37           6.0         63.7      6         False  ...
# 16461            3.35           7.0        182.8      4         False  ...
# 13749            3.40           7.0        218.0      7         False  ...
# 5893             2.80           7.0          NaN      7         False  ...
# 8900             2.80           8.0        132.0      7         False  ...
# 19865            3.90           6.0        260.0      3         False  ...
# 19155            2.80           5.0        145.0      4         False  ...
# 2536             3.85           9.0        131.0      7         False  ...
# 16495            2.80           5.0        180.0      4         False  ...
# 1026             5.30           3.0        190.0      3         False  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 12971           NaN        2  Санкт-Петербург           25108.0
# 19540         112.0        0  Санкт-Петербург           30706.0
# 14706          24.0        3  Санкт-Петербург           21912.0
# 1436           40.0        0  Санкт-Петербург           23011.0
# 15651          70.0        0  Санкт-Петербург           32440.0
# 22831          30.2        0  Санкт-Петербург           22494.0
# 16461          29.8        0  Санкт-Петербург           33143.0
# 13749          40.0        0  Санкт-Петербург           32440.0
# 5893           40.0        0  Санкт-Петербург           32440.0
# 8900           40.0        0  Санкт-Петербург           32440.0
# 19865          45.0        0  Санкт-Петербург           23962.0
# 19155          33.0        0  Санкт-Петербург           22640.0
# 2536           20.0        0  Санкт-Петербург           21946.0
# 16495          30.0        2  Санкт-Петербург           21740.0
# 1026           63.0        2  Санкт-Петербург           24899.0
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 12971              3956.0                 1          530.0                 3
# 19540              7877.0                 0            NaN                 2
# 14706              2389.0                 1          545.0                 1
# 1436               1197.0                 3          519.0                 3
# 15651              5297.0                 0            NaN                 2
# 22831              1073.0                 3          386.0                 3
# 16461              6235.0                 3          400.0                 3
# 13749              5297.0                 0            NaN                 2
# 5893               5297.0                 0            NaN                 2
# 8900               5297.0                 0            NaN                 2
# 19865              3794.0                 2          537.0                 3
# 19155               555.0                 3          285.0                 1
# 2536               2242.0                 1          679.0                 1
# 16495               436.0                 2          138.0                 3
# 1026               4785.0                 0            NaN                 1
#
#        ponds_nearest  days_exposition
# 12971          756.0             33.0
# 19540          318.0            106.0
# 14706          478.0            393.0
# 1436           285.0            233.0
# 15651          198.0            111.0
# 22831          188.0              NaN
# 16461          140.0            249.0
# 13749          198.0            199.0
# 5893           198.0             50.0
# 8900           198.0            901.0
# 19865          501.0            834.0
# 19155          200.0             18.0
# 2536           227.0            501.0
# 16495          620.0            178.0
# 1026           603.0              NaN
#
# [15 rows x 22 columns]

# %%
df = df[df['last_price'] < 160000000]

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Здорово, что  проверяешь данные не "на глаз". Лучше посмотреть на выбросы и аномалии данных математически, и удалить их с помощью специального метода boxplot()

# %%
df.boxplot(column='last_price', figsize=(10,10))
pass

# %% [markdown]
# Также посмотрим на минимальный порог. Есть ли ненормальные цены:

# %%
df[df['last_price'] < 400000]
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 8793             7       12190       109.0           2019-03-20      2
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 8793            2.75          25.0         32.0     25         False  ...
#
#       kitchen_area  balcony    locality_name  airports_nearest  \
# 8793          40.5        0  Санкт-Петербург           36421.0
#
#      cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 8793              9176.0                 1          805.0                 0
#
#       ponds_nearest  days_exposition
# 8793            NaN              8.0
#
# [1 rows x 22 columns]

# %%
df = df[(df['last_price'] < 100000000) & (df['last_price'] > 400000)]

# %% [markdown]
# Выбрали цифру 100000000, так как на графике видно, что выше лишь аномалии

# %% [markdown]
# Пройдемся по другим столбцам, чтобы определить явные выбросы

# %%
df_to_analyze = df.drop(columns='last_price')#Создадим заглушку для того, чтобы проверить графики размаха других столбцов
df_to_analyze.boxplot(figsize=(20,10))
pass

# %%
df_to_analyze_2 = df_to_analyze.drop(columns=['airports_nearest', 'cityCenters_nearest'])#Заглушка №2
df_to_analyze_2.boxplot(figsize=(20,10))
pass

# %% [markdown]
# Явных аномалий нет.

# %%
df = df.rename(columns={'locality_name': 'location','cityCenters_nearest': 'city_center_nearest', \
                        'parks_around3000':'parks_around_3km', 'ponds_around3000':'ponds_around_3km' })

# %% [markdown]
# Напоследок переименуем столбцы для удобства и чтобы было по правилам

# %% [markdown]
# Также стоит проверить DataFrame на явные дубликаты. Хоть на первый взгляд их нет, но нужно быть уверенным в этом.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# И все же задвоений не оказалось. Отлично, меньше работы.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Супер, старайся, пожалуйста, придерживаться этой стратегии в дальнейших проектах =)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Отсутствует проверка на явные дубликаты, поправишь, пожалуйста?

# %% [markdown]
# ✔️

# %% [markdown]
# **Вывод по разделу 2:**
#
# В результате проведенной предобработки разобрались с бОльшим количеством пропусков. Избавились от явных аномалий, явных дубликатов, пытаясь сохранить как можно больше строк. Переименовали значения для одного стиля, а также колонки для удобства работы. DataFrame готов к анализу.

# %% [markdown]
# ### Добавьте в таблицу новые столбцы

# %% [markdown]
# #### Добавляем столбец со стоимостью квадратного метра

# %%
df['quad_m_cost'] = round(df['last_price'] / df['total_area'], 2)

# %% [markdown]
# #### Добавляем столбцы с днем, месяцем и годом создания объявления

# %% [markdown]
# <div style="border:solid Aqua 3px; padding: 20px">
#
# __Комментарий №1__
#
# Попытка по-русски записать названия дней недели, используя внутренние библиотеки
#
# ```python
# import locale
# locale.setlocale(locale.LC_ALL, 'tt_RU.utf8')
# df['first_day_exposition'].dt.day_name(locale ='tt_RU.utf8')
# ```
#
# Почти получилось по-русски, но так как это не моя система, судя по всему русский не поддерживается :(

# %%
df['publication_day'] = df['first_day_exposition'].dt.day_name()

# %%
df['publication_month'] = df['first_day_exposition'].dt.month_name()

# %%
df['publication_year'] = df['first_day_exposition'].dt.to_period("Y")
df['publication_year'] = df['publication_year'].astype(str)#Потом оказывается, что только тип данных года не str

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Совет на будущие работы `(в этом проекте этот метод не нужен)`: обычно в датафреймах содержатся данные за несколько лет. Важно выбрать корректный метод для вычленения месяца, иначе месяца разных годов могут стать одним месяцем. Обрати внимание на метод astype('datetime64[M]'). Для его использования не нужно обращаться к pd.DatetimeIndex.
#
# Вот хорошая статья на этот счёт:
#
#      https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html
#
#     и
#
#     https://www.sharpsightlabs.com/blog/pandas-astype/
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Этот метод нужен для визуализации динамики по неделям, месяцам или годам (смотря какой метод выберешь)
#
# Код выглядит так:
#
#         df['first_day_exposition'].dt.date #приводим к временному формату
#         df['first_day_exposition'].astype('datetime64[M]')
#
# Если года разные, то в новой колонке месяца у тебя отобразится первый день месяца ('2019-05-01')
# </div>

# %% [markdown]
# Мы все знаем английский язык(надеюсь), так что оставим так. Конечно, можно переименовать на русский мотив, но это лишняя работа

# %%
df.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000      108.00           2019-03-07      3
# 1             7     3350000       40.40           2018-12-04      1
# 2            10     5196000       56.00           2015-08-20      2
# 3             0    64900000      159.00           2015-07-24      3
# 4             2    10000000      100.00           2018-06-19      2
# 5            10     2890000       30.40           2018-09-10      1
# 6             6     3700000       37.30           2017-11-02      1
# 7             5     7915000       71.60           2019-04-18      2
# 8            20     2900000       33.16           2018-05-23      1
# 9            18     5400000       61.00           2017-02-26      3
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0        51.00      8         False  ...
# 1            2.64          11.0        18.60      1         False  ...
# 2            2.80           5.0        34.30      4         False  ...
# 3            2.80          14.0          NaN      9         False  ...
# 4            3.03          14.0        32.00     13         False  ...
# 5            2.62          12.0        14.40      5         False  ...
# 6            2.63          26.0        10.60      6         False  ...
# 7            2.80          24.0          NaN     22         False  ...
# 8            2.94          27.0        15.43     26         False  ...
# 9            2.50           9.0        43.60      7         False  ...
#
#    city_center_nearest  parks_around_3km  parks_nearest  ponds_around_3km  \
# 0              16028.0                 1          482.0                 2
# 1              18603.0                 0            NaN                 0
# 2              13933.0                 1           90.0                 2
# 3               6800.0                 2           84.0                 3
# 4               8098.0                 2          112.0                 1
# 5                  NaN                 0            NaN                 0
# 6              19143.0                 0            NaN                 0
# 7              11634.0                 0            NaN                 0
# 8                  NaN                 0            NaN                 0
# 9              15008.0                 0            NaN                 0
#
#   ponds_nearest  days_exposition  quad_m_cost  publication_day  \
# 0         755.0              NaN    120370.37         Thursday
# 1           NaN             81.0     82920.79          Tuesday
# 2         574.0            558.0     92785.71         Thursday
# 3         234.0            424.0    408176.10           Friday
# 4          48.0            121.0    100000.00          Tuesday
# 5           NaN             55.0     95065.79           Monday
# 6           NaN            155.0     99195.71         Thursday
# 7           NaN              NaN    110544.69         Thursday
# 8           NaN            189.0     87454.76        Wednesday
# 9           NaN            289.0     88524.59           Sunday
#
#    publication_month  publication_year
# 0              March              2019
# 1           December              2018
# 2             August              2015
# 3               July              2015
# 4               June              2018
# 5          September              2018
# 6           November              2017
# 7              April              2019
# 8                May              2018
# 9           February              2017
#
# [10 rows x 26 columns]

# %% [markdown]
# #### Добавляем столбец с типом этажа

# %%
def floor(row):
    if row['floor'] == row['floors_total']:
        return 'Last'
    elif row['floor'] == 1:
        return 'First'
    else:
        return 'Else'

# %%
df['floor_type'] = df.apply(floor, axis=1)

# %%
df['floor_type'].unique()
# Out:
# array(['Else', 'First', 'Last'], dtype=object)

# %% [markdown]
# Все значения как надо, значит ошибок не вышло

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо бы проверить функцию, вывев уникальные значения нового столбца

# %% [markdown]
# ✔️

# %% [markdown]
# #### Добавляем столбец с расстоянием до центра в км

# %%
#df['city_center_nearest_km'] = (df['city_center_nearest'] / 1000).astype('int64', errors='ignore')

# %%
df['city_center_nearest_km'] = round((df['city_center_nearest'] / 1000), 0)

# %% [markdown]
# <div style="border:solid Aqua 3px; padding: 20px">
#
# __Комментарий №1__
#
# Здесь по-хорошему нужно бы подойти серьезнее к округлению, так как Python использует Банкосвское округление, а нам нужно обычное(можно написать формулу руками), но из-за NaN не можем преобразовать в численный тип данных

# %% [markdown]
# <div style="border:solid Aqua 3px; padding: 20px">
#
# __Комментарий №2__
#
# Слушай, сделал я так, как ты написал, но тут вылезает иинтересная ситуация. Из-за того, что он не может перевести NaN в int, то все данные так и остаются, как object64 = float. И по факту так и будет 3 знака после запятых(я проверил). Так что все же выходит надо возвращаться до round() (((

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Можно вот так:
#
#     data['cityCenters_nearest_km'] = (data['cityCenters_nearest'] / 1000).astype('int64', errors='ignore')

# %% [markdown]
# ✔️

# %% [markdown]
# **Вывод по разделу 3:**
#
# Отредактировали DataFrame, добавив нужные столбцы для анализа. Кое-где категоризировали переменные, где-то создали соверешнно новые значения в результате взаимодействий со столбцами. Подготовили почву для проведения исследовательского анализа.

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# #### Изучение параметров DataFrame ####
# - **1** Total_area

# %%
pd.Series(df['total_area']).plot(kind='hist', bins=50, range=(0,350), grid=True, title='Общая площадь')
plt.xlabel('Метры')
plt.ylabel('Частота появления')
pass

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Здорово, что используешь метод range() для определения пиковых значений
# </div>

# %%
df.boxplot(column='total_area', figsize=(10,15))
pass

# %% [markdown]
# В целом ничего необычного, есть небольшое количество выбросов, но их можно оставить.

# %% [markdown]
# - **2** Living_area

# %%
pd.Series(df['living_area']).plot(kind='hist', bins=50, range=(0,200), grid=True, title='Площадь жилой части')
plt.xlabel('Метры')
plt.ylabel('Частота появления')
pass

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Рекомендую оформлять визуализацию подписями осей абсцисс/ординат и заголовки.
#
#     plt.title('Название заголовка')
#     plt.ylabel('Название оси ординат')
#     plt.xlabel('Название оси абсцисс')
#     plt.show()

# %% [markdown]
# ✔️

# %%
df[df['living_area'] < 25]['location'].value_counts()
# Out:
# Санкт-Петербург                     4679
# поселок Мурино                       337
# поселок Парголово                    186
# поселок Шушары                       176
# деревня Кудрово                      169
#                                     ...
# садовое товарищество Новая Ропша       1
# деревня Ям-Тесово                      1
# деревня Лопухинка                      1
# деревня Извара                         1
# поселок Каложицы                       1
# Name: location, Length: 208, dtype: int64

# %% [markdown]
# Здесь, в целом, тоже все в порядке. Скачки из-за типов квартир. Код сверху это доказывает(так как типовые квартиры расположены в городах и там одинаковый метраж и планировка).

# %% [markdown]
# - **3** Kitchen_area

# %%
pd.Series(df['kitchen_area']).plot(kind='hist', bins=50, range=(0,55), grid=True, title='Площадь кухни')
plt.xlabel('Метры')
plt.ylabel('Частота появления')
pass

# %% [markdown]
# Здесь тоже все в порядке. Нормальное распределение.

# %% [markdown]
# - **4** Last_price

# %%
pd.Series(df['last_price']).plot(kind='hist', bins=100, grid=True, title='последняя цена')
plt.xlabel('Цена')
plt.ylabel('Частота появления')
pass

# %%
df[df['last_price'] > 40000000]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 3                 0    64900000       159.0           2015-07-24      3
# 51                7    45000000       161.0           2017-10-17      3
# 155               8    96000000       317.0           2017-07-07      4
# 411               1    40662000       151.0           2014-12-09      3
# 464              15    66571000       280.3           2015-06-11      6
# ...             ...         ...         ...                  ...    ...
# 22633            18    47500000       125.0           2016-06-27      3
# 22709            20    59000000       127.5           2016-12-21      4
# 22804             4    81960000       205.0           2017-09-29      4
# 22907             9    65000000       228.0           2016-06-02      4
# 23574            14    64990000       139.0           2015-11-24      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 3                 2.8          14.0          NaN      9         False  ...
# 51                3.2           8.0         38.0      4         False  ...
# 155               3.5           3.0        183.0      3         False  ...
# 411               2.8           8.0         85.0      3         False  ...
# 464               5.2           8.0        159.5      7         False  ...
# ...               ...           ...          ...    ...           ...  ...
# 22633             2.8           8.0         67.0      2         False  ...
# 22709             3.0          12.0         85.0      8         False  ...
# 22804             3.2           9.0        108.0      3         False  ...
# 22907             2.8           5.0        200.0      2         False  ...
# 23574             3.0           8.0          3.0      8         False  ...
#
#        parks_nearest  ponds_around_3km  ponds_nearest  days_exposition  \
# 3               84.0                 3          234.0            424.0
# 51               NaN                 3           99.0            541.0
# 155            508.0                 3          366.0             62.0
# 411            630.0                 3          100.0            594.0
# 464            187.0                 1          616.0            578.0
# ...              ...               ...            ...              ...
# 22633          125.0                 0            NaN            252.0
# 22709           84.0                 3          234.0            635.0
# 22804          679.0                 1          227.0            169.0
# 22907          619.0                 3          269.0              NaN
# 23574          630.0                 3          100.0            280.0
#
#       quad_m_cost  publication_day  publication_month  publication_year  \
# 3       408176.10           Friday               July              2015
# 51      279503.11          Tuesday            October              2017
# 155     302839.12           Friday               July              2017
# 411     269284.77          Tuesday           December              2014
# 464     237499.11         Thursday               June              2015
# ...           ...              ...                ...               ...
# 22633   380000.00           Monday               June              2016
# 22709   462745.10        Wednesday           December              2016
# 22804   399804.88           Friday          September              2017
# 22907   285087.72         Thursday               June              2016
# 23574   467553.96          Tuesday           November              2015
#
#        floor_type  city_center_nearest_km
# 3            Else                     7.0
# 51           Else                     7.0
# 155          Last                     2.0
# 411          Else                     6.0
# 464          Else                     7.0
# ...           ...                     ...
# 22633        Else                     6.0
# 22709        Else                     7.0
# 22804        Else                     2.0
# 22907        Else                     1.0
# 23574        Last                     6.0
#
# [145 rows x 28 columns]

# %% [markdown]
# Видим, что все равно 28 значений немного выбивают график. Мы уже избавились от совсем невозможных значений ранее. Лучше их оставить.

# %% [markdown]
# - **5** Rooms

# %%
pd.Series(df['rooms']).plot(kind='hist', bins=50, grid=True, title='комнаты')
plt.xlabel('Количество комнат')
plt.ylabel('Частота появления')
pass

# %% [markdown]
# Увидели, что есть квартиры с 0 комнат. В теории это возможно(изба это 0-комнатное жилое помещение). Но для этого надо кое-что проверить:

# %%
df[df['rooms'] == 0]['location'].value_counts()
# Out:
# Санкт-Петербург                 110
# поселок Мурино                   27
# деревня Кудрово                  16
# Никольское                        6
# Всеволожск                        6
# Кудрово                           5
# поселок Шушары                    4
# поселок Парголово                 4
# поселок Бугры                     3
# Сертолово                         3
# поселок Новоселье                 2
# Отрадное                          1
# деревня Новое Девяткино           1
# Мурино                            1
# поселок типа имени Свердлова      1
# поселок Новый Свет                1
# поселок Большая Ижора             1
# поселок Петро-Славянка            1
# поселок Янино-1                   1
# Тосно                             1
# поселок станции Корнево           1
# поселок типа Дубровка             1
# Name: location, dtype: int64

# %% [markdown]
# В Питере это буквально абсурд. В Санкт-Петербурге такое невозможно

# %%
df[df['rooms'] == 0] = df[(df['rooms'] == 0) & ~(df['location'] == 'Санкт-Петербург')]
df = df.dropna(subset=['total_images']) #Так как в этом столбце не было NaN до этого, а в rooms еще остались

# %%
df=df[df['rooms'] <7]

# %% [markdown]
# Бессмысслено измерять с количеством комнат больше 7

# %% [markdown]
# - **6** Ceiling_height

# %%
pd.Series(df['ceiling_height']).value_counts().reset_index().sort_values(by='index')
# Out:
#       index  ceiling_height
# 176    1.00               1
# 138    1.20               1
# 153    1.75               1
# 63     2.00              11
# 146    2.20               1
# ..      ...             ...
# 172   26.00               1
# 70    27.00               9
# 137   27.50               1
# 126   32.00               2
# 142  100.00               1
#
# [179 rows x 2 columns]

# %% [markdown]
# В теории значения действительно могли записать как вещественные, так что поступим так - разделим все высокие значения на 10, а потом удалим все строки, не соответствующие стандарту - больше 4.5 метров

# %%
df.loc[df['ceiling_height'] > 10, 'ceiling_height'] = df[df['ceiling_height'] > 10]['ceiling_height'] / 10

# %%
df = df[df['ceiling_height'] < 4.5]

# %%
pd.Series(df['ceiling_height']).plot(kind='hist', bins=20, grid=True, title='Высота потолков', range=(0, 4.5))
plt.xlabel('Метры')
plt.ylabel('Частота появления')
pass

# %% [markdown]
# - **7** Floor_type

# %%
counts = df['floor_type'].value_counts()
plt.bar(counts.index, counts.values)
plt.ylabel('Частота появления')
plt.xlabel('Тип этажа')
plt.title('Типы этажей')
pass

# %% [markdown]
# Очевидно, что количество квартир с последним или первым этажом куда меньше, чем остальных. Кстати, количество первых примерно равно количеству последних, значит все в порядке

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Полученные данные соответствуют реалиям
# </div>

# %% [markdown]
# - **8** Floors_total

# %%
pd.Series(df['floors_total']).plot(kind='hist', bins=100, grid=True, title='Общее количество этажей')
plt.xlabel('Этажей в здании')
plt.ylabel('Частота появления')
pass

# %%
df[df['floors_total'] >30]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 397            15.0   5990000.0        54.0           2018-03-22    2.0
# 871            14.0   7777777.0        75.0           2017-11-16    2.0
# 1060           10.0   5200000.0        50.0           2015-11-06    2.0
# 1697           11.0   3550000.0        28.0           2018-02-08    1.0
# 1917           13.0  10150000.0        74.0           2017-11-17    2.0
# 2253           12.0   3800000.0        45.5           2018-06-28    2.0
# 2966            9.0   4300000.0        37.0           2017-08-08    1.0
# 4855           12.0   5500000.0        50.0           2017-06-22    1.0
# 5807           17.0   8150000.0        80.0           2019-01-09    2.0
# 5808           12.0   4590000.0        43.0           2018-10-19    1.0
# 7236           10.0   4599000.0        42.0           2019-01-10    1.0
# 8496           20.0   7500000.0        73.3           2017-05-18    3.0
# 9186            7.0   6500000.0        49.1           2019-04-12    1.0
# 9370           12.0   7390000.0        70.0           2017-02-21    2.0
# 11079          16.0   9200000.0        75.0           2019-02-22    2.0
# 11575           9.0   9900000.0       101.0           2016-04-28    3.0
# 12888           7.0   7600000.0        70.0           2016-11-18    3.0
# 12960          20.0   6140000.0        54.0           2018-10-09    2.0
# 13975          19.0   6990000.0        65.0           2018-10-06    2.0
# 14347          14.0   8595000.0        69.7           2018-09-26    2.0
# 15982           1.0   5900000.0        62.0           2015-03-01    2.0
# 16731           9.0   3978000.0        40.0           2018-09-24    1.0
# 16934           5.0   4100000.0        40.0           2017-10-17    1.0
# 18218           4.0   9900000.0       101.0           2018-09-27    3.0
# 18617           8.0   7350000.0        68.5           2017-10-09    2.0
# 18629          20.0   5700000.0        54.0           2017-12-08    1.0
# 20938          18.0   9900000.0       100.9           2019-04-08    3.0
# 21599          12.0   6200000.0        51.0           2017-08-27    2.0
# 21809          20.0  10600000.0        77.0           2019-04-16    2.0
# 22946          14.0   7690000.0        75.0           2018-03-27    2.0
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 397              2.80          36.0         21.4   28.0        False  ...
# 871              2.80          35.0         40.5   23.0        False  ...
# 1060             2.80          35.0         39.0   15.0        False  ...
# 1697             2.65          34.0         18.0   23.0        False  ...
# 1917             2.80          35.0         34.4   30.0        False  ...
# 2253             2.88          60.0         27.4    4.0        False  ...
# 2966             2.80          35.0         14.0   15.0        False  ...
# 4855             2.80          35.0         22.0    4.0        False  ...
# 5807             2.70          36.0         41.0   13.0        False  ...
# 5808             2.80          35.0         14.0   11.0        False  ...
# 7236             2.80          35.0         15.0   12.0        False  ...
# 8496             2.80          35.0         28.0   27.0        False  ...
# 9186             2.50          35.0         31.0    3.0        False  ...
# 9370             2.70          35.0         28.0    3.0        False  ...
# 11079            2.70          36.0         40.0   29.0        False  ...
# 11575            2.80          33.0         53.0   32.0        False  ...
# 12888            2.70          35.0         36.5   27.0        False  ...
# 12960            2.70          35.0         26.6   13.0        False  ...
# 13975            2.80          35.0         32.1   23.0        False  ...
# 14347            2.80          35.0         27.4   26.0        False  ...
# 15982            2.80          35.0         34.0    9.0        False  ...
# 16731            2.65          52.0         10.5   18.0        False  ...
# 16934            1.75          37.0         17.4    5.0        False  ...
# 18218            2.80          35.0         53.4   33.0        False  ...
# 18617            2.80          35.0         27.0    3.0        False  ...
# 18629            2.80          35.0         21.0   31.0        False  ...
# 20938            2.80          35.0         53.4   22.0        False  ...
# 21599            2.80          35.0         27.0   13.0        False  ...
# 21809            2.80          35.0         39.0   11.0        False  ...
# 22946            2.80          35.0         40.0    8.0        False  ...
#
#       parks_nearest ponds_around_3km  ponds_nearest  days_exposition  \
# 397             NaN              3.0           80.0             11.0
# 871             NaN              3.0           80.0            169.0
# 1060            NaN              3.0           80.0            281.0
# 1697            NaN              3.0           80.0            410.0
# 1917            NaN              3.0           80.0              NaN
# 2253          342.0              3.0          614.0            166.0
# 2966            NaN              3.0           80.0             50.0
# 4855          609.0              3.0          145.0            537.0
# 5807            NaN              3.0           80.0             38.0
# 5808            NaN              3.0           80.0             82.0
# 7236            NaN              3.0           80.0             72.0
# 8496            NaN              3.0           80.0            250.0
# 9186            NaN              3.0           80.0              3.0
# 9370            NaN              3.0           80.0            236.0
# 11079           NaN              3.0           80.0              NaN
# 11575           NaN              3.0           80.0             53.0
# 12888           NaN              3.0           80.0            413.0
# 12960           NaN              3.0           80.0            155.0
# 13975           NaN              3.0           80.0             89.0
# 14347           NaN              3.0           80.0              NaN
# 15982           NaN              3.0           80.0            547.0
# 16731         793.0              0.0            NaN             45.0
# 16934           NaN              3.0           80.0             71.0
# 18218           NaN              3.0           72.0              7.0
# 18617         609.0              3.0          145.0             41.0
# 18629           NaN              3.0           80.0            128.0
# 20938           NaN              3.0           80.0              NaN
# 21599           NaN              3.0           80.0              NaN
# 21809           NaN              3.0           80.0              NaN
# 22946           NaN              3.0           80.0              NaN
#
#       quad_m_cost  publication_day  publication_month  publication_year  \
# 397     110925.93         Thursday              March              2018
# 871     103703.69         Thursday           November              2017
# 1060    104000.00           Friday           November              2015
# 1697    126785.71         Thursday           February              2018
# 1917    137162.16           Friday           November              2017
# 2253     83516.48         Thursday               June              2018
# 2966    116216.22          Tuesday             August              2017
# 4855    110000.00         Thursday               June              2017
# 5807    101875.00        Wednesday            January              2019
# 5808    106744.19           Friday            October              2018
# 7236    109500.00         Thursday            January              2019
# 8496    102319.24         Thursday                May              2017
# 9186    132382.89           Friday              April              2019
# 9370    105571.43          Tuesday           February              2017
# 11079   122666.67           Friday           February              2019
# 11575    98019.80         Thursday              April              2016
# 12888   108571.43           Friday           November              2016
# 12960   113703.70          Tuesday            October              2018
# 13975   107538.46         Saturday            October              2018
# 14347   123314.20        Wednesday          September              2018
# 15982    95161.29           Sunday              March              2015
# 16731    99450.00           Monday          September              2018
# 16934   102500.00          Tuesday            October              2017
# 18218    98019.80         Thursday          September              2018
# 18617   107299.27           Monday            October              2017
# 18629   105555.56           Friday           December              2017
# 20938    98116.95           Monday              April              2019
# 21599   121568.63           Sunday             August              2017
# 21809   137662.34          Tuesday              April              2019
# 22946   102533.33          Tuesday              March              2018
#
#        floor_type  city_center_nearest_km
# 397          Else                    20.0
# 871          Else                    20.0
# 1060         Else                    20.0
# 1697         Else                    20.0
# 1917         Else                    20.0
# 2253         Else                    49.0
# 2966         Else                    20.0
# 4855         Else                    20.0
# 5807         Else                    20.0
# 5808         Else                    20.0
# 7236         Else                    20.0
# 8496         Else                    20.0
# 9186         Else                    20.0
# 9370         Else                    20.0
# 11079        Else                    20.0
# 11575        Else                    20.0
# 12888        Else                    20.0
# 12960        Else                    20.0
# 13975        Else                    20.0
# 14347        Else                    20.0
# 15982        Else                    20.0
# 16731        Else                    13.0
# 16934        Else                    20.0
# 18218        Else                    20.0
# 18617        Else                    20.0
# 18629        Else                    20.0
# 20938        Else                    20.0
# 21599        Else                    20.0
# 21809        Else                    20.0
# 22946        Else                    20.0
#
# [30 rows x 28 columns]

# %% [markdown]
# Исходя из того, что средний уровень этажа равен 3 метра и взяв междуэтажное расстояние примерно в 1 метр получаем, что для здания с 30+ этажей высота должна составлять 120+ метров, что уже является небоскребом(нежилым зданием). Отбросим эти значения, так как они не подходят для анализа

# %%
df = df[df['floors_total'] < 30]

# %% [markdown]
# - **9** City_center_nearest

# %%
pd.Series(df['city_center_nearest']).plot(kind='hist', bins=100, grid=True, title='Ближайший центр города')
plt.xlabel('Метры')
plt.ylabel('Частота появления')
pass

# %% [markdown]
# Тяжело что-либо сказать. Речи о распределении быть не может на этом графике.

# %%
df.boxplot(column='city_center_nearest',figsize=(10,10))
pass

# %% [markdown]
# Оставляем как есть

# %% [markdown]
# - **10** Parks_nearest

# %%
pd.Series(df['parks_nearest']).plot(kind='hist', bins=100, grid=True, title='Ближайший парк')
plt.xlabel('Метры')
plt.ylabel('Частота появления')
pass

# %% [markdown]
# Та же ситуация, что и с центрами города, хотя тут больше похоже на нормальное распределение.

# %% [markdown]
# #### Изучим, как быстро продавались квартиры

# %%
pd.Series(df['days_exposition']).plot(kind='hist', bins=100, grid=True, title='Время объявления')
plt.xlabel('Дни')
plt.ylabel('Частота появления')
pass

# %%
selling_speed = df.groupby('location').days_exposition.agg(mean=(lambda x: round(x.mean(), 2)), median='median')

# %%
selling_speed = selling_speed.dropna()
selling_speed.sort_values('mean', ascending=False)
# Out:
#                                    mean  median
# location
# деревня Рабитицы                 1007.0  1007.0
# поселок Молодежное                786.0  1043.0
# поселок Коробицыно                750.0   750.0
# поселок типа Рябово               647.0   647.0
# деревня Большая Пустомержа        627.0   627.0
# ...                                 ...     ...
# поселок Платформа 69-й километр    18.0    18.0
# поселок Новогорелово               17.9    10.0
# коттеджный поселок Счастье          7.0     7.0
# поселок Заводской                   5.0     5.0
# поселок типа Форносово              3.0     3.0
#
# [242 rows x 2 columns]

# %%
selling_speed.sort_values('median', ascending=False)
# Out:
#                                mean  median
# location
# поселок Молодежное           786.00  1043.0
# деревня Рабитицы            1007.00  1007.0
# поселок Коробицыно           750.00   750.0
# поселок Любань               531.00   654.0
# поселок типа Рябово          647.00   647.0
# ...                             ...     ...
# поселок Новогорелово          17.90    10.0
# деревня Яльгелево             33.67     7.0
# коттеджный поселок Счастье     7.00     7.0
# поселок Заводской              5.00     5.0
# поселок типа Форносово         3.00     3.0
#
# [242 rows x 2 columns]

# %%
pd.Series(selling_speed['mean']).plot(kind='hist', bins=100, grid=True, title='Среднее продаж по населенным пунктам')
plt.ylabel('Частота появления')
plt.xlabel('Цена')
pass

# %%
pd.Series(selling_speed['median']).plot(kind='hist', bins=100, grid=True, title='Медиана продаж по населенным пунктам')
plt.ylabel('Частота появления')
plt.xlabel('Цена')
pass

# %% [markdown]
# Рассмотрим более детально медиану:

# %%
selling_speed.boxplot(column='median')
pass

# %%
selling_speed['median'].describe()
# Out:
# count     242.000000
# mean      162.541322
# std       151.349018
# min         3.000000
# 25%        76.125000
# 50%       113.750000
# 75%       185.500000
# max      1043.000000
# Name: median, dtype: float64

# %% [markdown]
# Изходя из более подробного рассмотрения, можно увидеть, что медиана медиан продаж по городам находится на отметке 162. В целом логично предположить, что продажи до отметки q1 = 76 считаются "быстрыми", то есть быстрее, чем обычно. Продажи после этой отметки, но не позднее значения q3 = 185 - "Средние". Продажи позднее средних, но до значения полутораквартильного расстояния (q3-q1)\*1,5+q3 = 348 - "Долгие". Продажи после этой отметки - "Необычайно долгие". Резюмируем информацию:
# * Продажи <= 76 дней = "Быстрые"
# * 76 дней < Продажи <= 185 дней = "Средние"
# * 185 дней < Продажи <= 348 дней = "Долгие"
# * Продажи > 348 дней = "Необычайно долгие"

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Немного не так, чтобы ответить на вопрос "Какие продажи можно считать быстрыми, а какие — необычно долгими?" лучше посмотреть на распределение данных с помощью boxplot() или describe().
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Тут согласен

# %% [markdown]
# ✔️

# %% [markdown]
# #### Изучим факторы, влияющии на цену ####

# %% [markdown]
# Для подготовки с некоторыми сравнениям сделаем сводные таблицы. но для некоторых будем использовать диаграмму рассеяния, так как значений очень много

# %% [markdown]
# - **1** Связь с общей площадью

# %%
df.plot(x='last_price', y='total_area', kind='scatter', grid=True, title='Общая площадь/цена')
plt.ylabel('Общая площадь')
plt.xlabel('Последняя цена')
pass

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Здорово, что зависимость нелинейных данных рассматриваешь через тип графика scatter
# </div>

# %%
df[['last_price', 'total_area']].corr()
# Out:
#             last_price  total_area
# last_price    1.000000    0.757939
# total_area    0.757939    1.000000

# %% [markdown]
# Ну тут у нас почти прямая зависимость в начале, дальше больше рассеивается, но в целом зависимость продолжается. Коэффициент корреляции поддерживает данный вывод.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Верная интерпретация значений корреляции Пирсона. Ты молодец =)
# </div>

# %% [markdown]
# - **2** Связь с жилой площадью

# %%
df.plot(x='last_price', y='living_area', kind='scatter', grid=True, title='Жилая площадь/Цена')
plt.ylabel('Жилая площадь')
plt.xlabel('Последняя цена')
pass

# %%
df[['last_price', 'living_area']].corr()
# Out:
#              last_price  living_area
# last_price     1.000000     0.665821
# living_area    0.665821     1.000000

# %% [markdown]
# Есть небольшие выбросы, но в целом зависимость также прямая, хотя коэффициент уже падает.

# %% [markdown]
# - **3** Связь с площадью кухни

# %%
df.plot(x='last_price', y='kitchen_area', kind='scatter', grid=True, title='Площадь кухни/Цена')
plt.ylabel('Площадь кухни')
plt.xlabel('Последняя цена')
pass

# %%
df[['last_price', 'kitchen_area']].corr()
# Out:
#               last_price  kitchen_area
# last_price      1.000000      0.588381
# kitchen_area    0.588381      1.000000

# %% [markdown]
# Вот тут уже не очень прямая. В целом не сильно зависит цена от площади кухни. Коэффициент также почти 0.5 - полный хаос.

# %% [markdown]
# - **4** Связь с количеством комнат

# %%
rooms = df.pivot_table(values='last_price', index='rooms', aggfunc='median')
plt.bar(rooms.index, rooms['last_price'].values)
plt.ylabel('Цена')
plt.xlabel('Количество комнат')
plt.title('Комнаты/Цена')
pass

# %% [markdown]
# Ну вот тут, как и хотелось, логичная прямая зависимость

# %% [markdown]
# - **5** Связь с типом этажа

# %%
floors = df.pivot_table(values='last_price', index='floor_type', aggfunc='median')
plt.bar(floors.index, floors['last_price'].values)
plt.ylabel('Цена')
plt.xlabel('Тип этажа')
plt.title('Тип этажа/Цена')
pass

# %% [markdown]
# На удивление одинаково, что странно, потому что квартир, очевидно, меньше. Это говорит о том, что люди готовы переплатить для квартир, расположенных на первом и последнем этажах

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Как в песне, "первый и последний этаж не предлагать". Традиционно, квартиры на первом и последнем этажах считаются самыми неудобными для жизни и это отражается на их стоимости.
# </div>

# %% [markdown]
# - **6** Связь с днем размещения объявления

# %%
days = df.pivot_table(values='last_price', index='publication_day', aggfunc='median')
plt.bar(days.index, days['last_price'].values)
plt.ylabel('Цена')
plt.xlabel('День недели')
plt.title('Продажи по дням')
pass

# %% [markdown]
# Не зависит от дня недели

# %% [markdown]
# - **7** Связь с месяцем размещения

# %%
months = df.pivot_table(values='last_price', index='publication_month', aggfunc='median')
plt.bar(months.index, months['last_price'].values)
plt.ylabel('Цена')
plt.xlabel('Месяц')
plt.title('Продажи по месяцам')
pass

# %% [markdown]
# Не зависит от месяца

# %% [markdown]
# - **8** Связь с годом размещения

# %%
years = df.pivot_table(values='last_price', index='publication_year', aggfunc='median')
plt.bar(years.index, years['last_price'].values)
plt.ylabel('Цена')
plt.xlabel('Год')
plt.title('Продажи по годам')
pass

# %% [markdown]
# А вот по годам есть зависимость. Куда больше дома стоили раньше, в самом первом году - 2014. Посмотрим глубже.

# %%
years_square = df.pivot_table(values='total_area', index='publication_year', aggfunc='median')
plt.bar(years_square.index, years_square['total_area'].values)
plt.ylabel('Общая площадь')
plt.xlabel('Год')
plt.title('Площадь продаваемых квартир по годам')
pass

# %% [markdown]
# Оказалось, что цена была напрямую связана с площадью, так что год все же не влияет на стоимость.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Давай рассмотрим динамику цены и площади продаваемых квартир. И потом пересмотрим выводы, т.к., возможно, упала не столько цена, сколько площадь продаваемых квартир?
# </div>

# %% [markdown]
# ✔️

# %% [markdown]
# #### Посчитаем среднюю цену квадратного метра

# %% [markdown]
# Выведем сводную таблицу, в которой будет 10 наибольших количеств объявлений по городам

# %%
quad_price = df.groupby('location').agg(number=('rooms','count'), avg_quad_m_price=('quad_m_cost', 'median')).\
sort_values('number', ascending=False).head(10)
quad_price
# Out:
#                    number  avg_quad_m_price
# location
# Санкт-Петербург     15382        104547.725
# поселок Мурино        552         86059.295
# поселок Шушары        439         76829.270
# Всеволожск            398         65789.470
# Пушкин                368         99993.590
# Колпино               337         74722.220
# поселок Парголово     326         91780.225
# Гатчина               307         67796.610
# деревня Кудрово       299         91860.470
# Выборг                236         58133.215

# %% [markdown]
# Город с наибольшей ценой квадартного метра

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Таблица верна. Совет: на общие продажи лучше смотреть через призму медианы. Она более устойчива к выбросам
# </div>

# %% [markdown]
# ✔️

# %%
quad_price[quad_price['avg_quad_m_price'] == quad_price['avg_quad_m_price'].max()]
# Out:
#                  number  avg_quad_m_price
# location
# Санкт-Петербург   15382        104547.725

# %% [markdown]
# С наименьшей ценой квадратного метра

# %%
quad_price[quad_price['avg_quad_m_price'] == quad_price['avg_quad_m_price'].min()]
# Out:
#           number  avg_quad_m_price
# location
# Выборг       236         58133.215

# %% [markdown]
# #### Вычислим среднюю стоимость квартир в Санкт-Петербурге по удаленности от центра

# %%
price = df[df['location'] == 'Санкт-Петербург'].groupby('city_center_nearest_km').\
agg(price_for_km=('last_price', lambda x: int(x.median())), number=('rooms', 'count'))

# %%
price = price[price['number'] > 30] #Отбросим те строки, где количество квартир небольшое(Да, мы отбросили 0 км тоже)
plt.bar(price.index, price['price_for_km'].values)
plt.title('Распределение цены по километрам от центра')
plt.xlabel('Километры от центра')
plt.ylabel('Цена')
pass

# %% [markdown]
# Из данной гистограммы можно сделать очевидный вывод о том, что чем ближе квартира к центру, тем она дороже. Но также возникает интересный момент на км = 3. Видимо, либо на такой удаленности мешает ландшафт(много рек), либо люди готовы переплатить только за 1-2 км.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отличная визуализация. В твой код добавил заголовок, посмотри, пожалуйста, этот момент. Очень важно оформлять графики
# </div>

# %% [markdown]
# **Вывод по разделу 4:**
#
# В ходе проведения исследовательского анализа рассмотрели самые важные компоненты DataFrame, а также сравнили влияние разных параметров на конечную цену(Результаты будут опубликованы в финальном выводе). Выделил города/поселки с максимальной/минимальной ценой за квадратный метр. Рассмотрели конкретно Санкт-Петербург, так как изначально было интересно, влияет ли расстояние от центра на стоимость. Получились необычные результаты.

# %% [markdown]
# ### Напишите общий вывод

# %% [markdown]
# - **1. Знакомство с DataFrame:**
# - **1.1** Рассмотрели данные со стороны применимости для анализа. Несмотря на определенное количество пропусков, полученная информация оказалась достаточной для начала анализирования.
# - **1.2** Построили гистограммы по каждому столбцу, чтобы понять, насколько данные приближены к реальности. В тех, где нужно, нашли около нормальное распределение, соответственно все в порядке.
# - **2. Предобработка DataFrame:**
# - **2.1** Во всех столбцах избавились от пропусков, пытаясь сохранить как можно больше строк. Удалили аномальные значения или заменили их на подходящие под соответствующие столбцы.
# - **2.2** Избавились от явных выбросов, явных дубликатов, которые могли бы повлиять на результаты исследований.
# - **2.3** Переименовали значения и столбцы для соответствия стандартам
# - **3. Добавление столбцов:**
# - **3.1** Добавили столбцы с категориями для упрощения вычислений.
# - **3.2** Провели базовые манипуляции для добавления столбцов, наиболее интересующих нас.
# - **3.3** Разделили дату на дни, месяцы и годы, создав соответствующие столбцы.
# - **4. Исследовательский анализ:**
# - **4.1** Изучение параметров:
# - **4.1.1** Рассмотрели все значимые параметры в DataFrame со стороны статистики и откорректировали значения для дальнейшего анализа.
# - **4.1.2** В результате получили полноценный DataFrame, в котором все значения находятся в пределах разумных.
# - **4.2** Рассмотрели, насколько быстро продавались квартиры. Построили графики, оценили скорость.
# - **4.2.1** Вывод из раздела:
#     * Продажи <= 76 дней = "Быстрые"
#     * 76 дней < Продажи <= 185 дней = "Средние"
#     * 185 дней < Продажи <= 348 дней = "Долгие"
#     * Продажи > 348 дней = "Необычайно долгие"
# - **4.3** Рассмотрели все значимые факторы, которые могут повлиять на общую цену.
# - **4.3.1** Вывод из раздела - на цену влияют:
#     * Общая площадь
#     * Жилая площадь
#     * Количество комнат
#
# Остальные факторы оказались недостаточно значимыми
# - **4.4** Оценка среднего квадратного метра по населенным пунктам.
# - **4.4.1** Изучили среднюю квадратуру регионов с наибольшим количеством объявлений, а также узнали, что в Санкт-Петербурге самый дорогой квадратный метр, а в Выборге - самый дешеый.
# - **4.5** Оценили стоимость объектов в Санкт-Петербурге в завимиости от удаленности от центра.
# - **4.5.1** Построили графики и нашли зависимость между ценой объекта и удаленностью от центра. Зависимость оказалась не до конца прямой. Удаленность в 3-5 километров выдает необычный результат, что может говорить о том, что большинство людей готовы переплачивать только за расстояние в 1-2 км.
# - **5.1 Результаты проведенного анализа:**
#     * Разобрались, с какой скоростью должна продаваться квартира, используя статистику и графики размаха
#     * Установили важнейшие факторы, влияющие на стоимость
#     * Рассчитали среднюю квадратуру для каждого населенного пункта
#     * Нашли необычную зависимость между расстоянием от центра и стоимостью

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Шикарный вывод и рекомендации для бизнеса. Кстати, хорошей практикой является написание в общем выводе всех твоих действий (кратко) по проекту. Ведь вывод раскрывает для заказчика всю твою проделанную работу и за что он платит деньги, даже если ему не интересен весь процесс исследования, то в отчёт он заглянет обязательно. Ты молодец!
# </div>

# %% [markdown]
# <div style="border:solid Aqua 3px; padding: 20px">
#
# __Комментарий №2__
#
# Учту в дальнейшем

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №1 </b>
#
#
#
# У тебя получилась очень сильная и хорошая работа. Здорово, что расчеты ты сопровождаешь иллюстрациями, а так же не забываешь про комментарии, твой проект интересно проверять.
#
# ---
#
# Нужно поправить:
#
#
# 1) Проверка на дубликаты
#
# 2) Какие продажи можно считать быстрыми, а какие — необычно долгими?
#
# 3) Подправить выводы, после изменений
#
# ----
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# - 1 ✔️
# - 2 ✔️
# - 3 ✔️

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-block alert-success">✔️
#
#
# __Коментарий от ревьюера №2__
#
#
# В остальном всё чудно😊. Твой проект так и просится на github =)
#
# Поздравляю с успешным завершением проекта 😊👍
# И желаю успехов в новых работах 😊
#
# ---
#
# От себя хочу порекомендовать тебе отличную книгу про язык Python. Она очень классная (можно купить как новую, так и на Авито попадается. Вот ссылка на pdf этой книги)
#
# https://monster-book.com/avtomatizaciya-zadach-s-python
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Файл с данными открыт.
# - [x]  Файл с данными изучен: выведены первые строки, использован метод `info()`, построены гистограммы.
# - [x]  Найдены пропущенные значения.
# - [x]  Пропущенные значения заполнены там, где это возможно.
# - [x]  Объяснено, какие пропущенные значения обнаружены.
# - [x]  В каждом столбце установлен корректный тип данных.
# - [x]  Объяснено, в каких столбцах изменён тип данных и почему.
# - [x]  Устранены неявные дубликаты в названиях населённых пунктов.
# - [x]  Обработаны редкие и выбивающиеся значения (аномалии).
# - [x]  В таблицу добавлены новые параметры:
#        – цена одного квадратного метра;
#        – день публикации объявления (0 - понедельник, 1 - вторник и т. д.);
#        – месяц публикации объявления;
#        – год публикации объявления;
#        – тип этажа квартиры (значения — «первый», «последний», «другой»);
#        – расстояние до центра города в километрах.
# - [x]  Изучены и описаны параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего парка.
# - [x]  Выполнено задание «Изучите, как быстро продавались квартиры (столбец `days_exposition`)»:
#     - построена гистограмма;
#     - рассчитаны среднее и медиана;
#     - описано, сколько обычно занимает продажа и указано, какие продажи можно считать быстрыми, а какие — необычно долгими.
# - [x]  Выполнено задание «Определите факторы, которые больше всего влияют на общую (полную) стоимость объекта». Построены графики, которые показывают зависимость цены от параметров:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - количество комнат;
#         - тип этажа, на котором расположена квартира (первый, последний, другой);
#         - дата размещения (день недели, месяц, год).
# - [x]  Выполнено задание «Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений»:
#     - выделены населённые пункты с самой высокой и низкой стоимостью квадратного метра.
# - [x]  Выполнено задание «Выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите их среднюю стоимость на разном удалении от центра»:
#     -  учтён каждый километр расстояния, известны средние цены квартир в одном километре от центра, в двух и так далее;
#     -  описано, как стоимость объекта зависит от расстояния до центра города;
#     -  построен график изменения средней цены для каждого километра от центра Петербурга.
# - [x]  На каждом этапе сделаны промежуточные выводы.
# - [x]  В конце проекта сделан общий вывод.
